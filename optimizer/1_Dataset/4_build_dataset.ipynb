# %%
import pandas as pd
import sys
import os
import numpy as np
sys.path.append(os.path.abspath("../.."))
from optimizer import variables

# %%
# price = pd.read_csv("2_Processed_data/price.csv")
generation = pd.read_csv("2_Processed_data/generation.csv")
lgc = pd.read_csv("2_Processed_data/lgc.csv").drop(columns=["Date"])
tariff = pd.read_csv("2_Processed_data/tariff.csv").drop(columns=["Date"])
physical_constraint = pd.read_csv("2_Processed_data/physical_constraint.csv").drop(columns=["Date"])
# protocol_signal = pd.read_csv("2_Processed_data/predicted_price.csv").drop(columns=["Date"])

# %%
df = pd.concat([generation,lgc,tariff,physical_constraint],axis=1)
df.to_csv("2_Processed_data/Dataset/dataset.csv",index=False)
